# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Model creation and training.
import torch
import torch.nn as nn
from transformer_components import (
    TransformerDecoder,
    TransformerEncoder,
    TransformerEncoderDecoder,
    get_causal_mask,
)
from torch.optim import Adam
import pickle

# Data download and decompression.
import os
import requests
import gzip
import shutil

# Data processing
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader
import spacy

# %%
# Set device to gpu if available
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
print("You are using device: %s" % device)
# Out:
# You are using device: cuda

# %% [markdown]
# ## Download and decompress the training, validation and test data.

# %%
MULTI30_URL = (
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/"
)
LOCAL_DATA_DIR = "multi30k"
DATA_FILES_CONFIG = {
    "train": {"en": "train.en.gz", "fr": "train.fr.gz"},
    "val": {"en": "val.en.gz", "fr": "val.fr.gz"},
    "test": {"en": "test_2016_flickr.en.gz", "fr": "test_2016_flickr.fr.gz"},
}
DATA_FILES_NAMES = [
    filename for split in DATA_FILES_CONFIG.values() for filename in split.values()
]

# Download data into a local directory.
os.makedirs(LOCAL_DATA_DIR, exist_ok=True)

for file_name in DATA_FILES_NAMES:

    local_path = os.path.join(LOCAL_DATA_DIR, file_name)
    decompressed_path = os.path.splitext(local_path)[0]

    if not os.path.exists(decompressed_path):

        # Download file.
        with requests.get(
            os.path.join(MULTI30_URL, file_name), stream=True
        ) as response:
            response.raise_for_status()
            with open(local_path, "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    f.write(chunk)

        # Decompress file.
        with gzip.open(local_path, "rb") as f_in:
            with open(decompressed_path, "wb") as f_out:
                shutil.copyfileobj(f_in, f_out)

        # Remove compressed version of file.
        os.remove(local_path)

# %% [markdown]
# ## Load the data from files into ram, and tokenize.

# %%
# To save time, save the data object. That way, spacy only needs tokenize the data once.
if os.path.exists("data_cache.pt"):
    data = torch.load("data_cache.pt", pickle_module=pickle)
else:
    spacy_en = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    spacy_fr = spacy.load("fr_core_news_sm", disable=["parser", "ner"])

    def load_data(eng_file_path, fr_file_path):

        pairs = []
        with open(eng_file_path, "r") as f1, open(fr_file_path, "r") as f2:
            for eng_line, fr_line in zip(f1, f2):
                eng_tokens = [
                    token.text.lower() for token in spacy_en(eng_line.strip())
                ]
                fr_tokens = [token.text.lower() for token in spacy_fr(fr_line.strip())]
                pairs.append((eng_tokens, fr_tokens))

        return pairs

    data = {}
    for split, langs in DATA_FILES_CONFIG.items():
        eng_file_path = os.path.join(LOCAL_DATA_DIR, os.path.splitext(langs["en"])[0])
        fr_file_path = os.path.join(LOCAL_DATA_DIR, os.path.splitext(langs["fr"])[0])

        data[split] = load_data(eng_file_path, fr_file_path)

    torch.save(data, "data_cache.pt")

data["train"][0]  # Example
# Out:
# (['two',
#   'young',
#   ',',
#   'white',
#   'males',
#   'are',
#   'outside',
#   'near',
#   'many',
#   'bushes',
#   '.'],
#  ['deux',
#   'jeunes',
#   'hommes',
#   'blancs',
#   'sont',
#   'dehors',
#   'près',
#   'de',
#   'buissons',
#   '.'])

# %% [markdown]
# ## Create English and French vocabularies.

# %%
PAD_TOKEN, PAD_IDX = "<PAD>", 0
SOS_TOKEN, SOS_IDX = "<SOS>", 1
EOS_TOKEN, EOS_IDX = "<EOS>", 2
UNK_TOKEN, UNK_IDX = "<UNK>", 3


class Vocab:

    def __init__(self):

        self.word_to_ordinal = {
            PAD_TOKEN: PAD_IDX,
            SOS_TOKEN: SOS_IDX,
            EOS_TOKEN: EOS_IDX,
            UNK_TOKEN: UNK_IDX,
        }
        self.ordinal_to_word = {
            PAD_IDX: PAD_TOKEN,
            SOS_IDX: SOS_TOKEN,
            EOS_IDX: EOS_TOKEN,
            UNK_IDX: UNK_TOKEN,
        }
        self.count = 4

    # This method builds the vocabulary, for each sentence passed in.
    def add_sentence(self, sentence):

        for word in sentence:
            if word not in self.word_to_ordinal:
                self.word_to_ordinal[word] = self.count
                self.ordinal_to_word[self.count] = word
                self.count += 1

    # This method is for creating model inputs.
    def to_ordinals(self, sentence):

        ordinal_sentence = [SOS_IDX]
        for word in sentence:
            ordinal_sentence.append(self.word_to_ordinal.get(word, UNK_IDX))
        ordinal_sentence.append(EOS_IDX)

        return torch.tensor(ordinal_sentence, dtype=torch.int64)

    # This method is for viewing model outputs.
    def to_words(self, ordinal_sentence):

        tokens = []
        for ordinal in ordinal_sentence:
            ordinal = ordinal.item()
            if ordinal == EOS_IDX:
                break
            if ordinal != SOS_IDX and ordinal != PAD_IDX:
                tokens.append(self.ordinal_to_word.get(ordinal, UNK_TOKEN))

        return " ".join(tokens)


# Build the vocabularies from training data.
en_vocab = Vocab()
fr_vocab = Vocab()

for en_fr_pair in data["train"]:
    en_vocab.add_sentence(en_fr_pair[0])
    fr_vocab.add_sentence(en_fr_pair[1])

# %% [markdown]
# ## Creating a dataloader for train, val, and test datasets.

# %%
class Multi30k(Dataset):

    def __init__(self, pairs, en_vocab, fr_vocab):
        super().__init__()

        self.ordinal_pairs = []
        for pair in pairs:
            ordinal_pair = (
                en_vocab.to_ordinals(pair[0]),
                fr_vocab.to_ordinals(pair[1]),
            )
            self.ordinal_pairs.append(ordinal_pair)

    def __len__(self):
        return len(self.ordinal_pairs)

    def __getitem__(self, index):
        return self.ordinal_pairs[index]

# %%
BATCH_SIZE = 16


def collate_fn(batch):
    X_src = pad_sequence(
        [batch[i][0] for i in range(len(batch))],
        batch_first=True,
        padding_value=PAD_IDX,
    )
    X_tgt = pad_sequence(
        [batch[i][1] for i in range(len(batch))],
        batch_first=True,
        padding_value=PAD_IDX,
    )
    return (X_src, X_tgt)


dataloaders = {}
for split, pairs in data.items():
    dataset = Multi30k(pairs, en_vocab, fr_vocab)
    dataloaders[split] = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=(split == "train"),  # Shuffle only True for training data
        collate_fn=collate_fn,
    )

# %% [markdown]
# ## Model creation and training loop.

# %%
# Wrapper for the TransformerEncoder that embeds tokens and adds positional encodings.
class Encoder(nn.Module):

    def __init__(self, transformer_encoder_config, vocab_size, context_size):
        super().__init__()

        self.embedding = nn.Embedding(
            vocab_size, transformer_encoder_config["hidden_size"]
        )
        self.positional_encoding = nn.Embedding(
            context_size, transformer_encoder_config["hidden_size"]
        )
        self.transformer_encoder = TransformerEncoder(**transformer_encoder_config)

    def forward(self, X, key_padding_mask):

        X = self.embedding(X) + self.positional_encoding(
            torch.arange(X.shape[1], device=X.device)
        )
        X = self.transformer_encoder(X, key_padding_mask)

        return X


# Similar idea to above.
class Decoder(nn.Module):

    def __init__(self, transformer_decoder_config, vocab_size, context_size):
        super().__init__()
        
        self.embedding = nn.Embedding(
            vocab_size, transformer_decoder_config["hidden_size"]
        )
        self.positional_encoding = nn.Embedding(
            context_size, transformer_decoder_config["hidden_size"]
        )
        self.project = nn.Linear(
            transformer_decoder_config["hidden_size"],
            vocab_size,
        )
        self.transformer_decoder = TransformerDecoder(**transformer_decoder_config)
        
        # Store for generate function 
        self.key_size = transformer_decoder_config["key_size"]
        self.value_size = transformer_decoder_config["value_size"]
        self.num_heads = transformer_decoder_config["num_heads"]
        self.vocab_size = vocab_size
        self.stack_size = transformer_decoder_config["stack_size"]


    def forward(
        self, X_tgt, X_src, tgt_mask, tgt_key_padding_mask, src_key_padding_mask, all_kv_cache=None
    ):

        X_tgt = self.embedding(X_tgt) + self.positional_encoding(
            torch.arange(X_tgt.shape[1], device=X_tgt.device)
        )
        features = self.transformer_decoder(
            X_tgt, X_src, tgt_mask, tgt_key_padding_mask, src_key_padding_mask, all_kv_cache
        )
        logits = self.project(features)

        return logits

# %%
CONTEXT_SIZE = 60  # The number of positional encodings to learn.

encoder_config = {
    "stack_size": 6,
    "num_heads": 8,
    "hidden_size": 512,
    "key_size": 64,
    "value_size": 64,
    "feedforward_size": 2048,
    "dropout": 0.1,
}

decoder_config = {
    "stack_size": 6,
    "num_heads": 8,
    "hidden_size": 512,
    "key_size": 64,
    "value_size": 64,
    "feedforward_size": 2048,
    "dropout": 0.1,
}

model = TransformerEncoderDecoder(
    Encoder(encoder_config, vocab_size=en_vocab.count, context_size=CONTEXT_SIZE),
    Decoder(decoder_config, vocab_size=fr_vocab.count, context_size=CONTEXT_SIZE),
).to(device)
criterion = torch.nn.CrossEntropyLoss(ignore_index=PAD_IDX)
optimizer = Adam(model.parameters(), lr=0.0001)

epochs_completed = 0

if os.path.exists("checkpoint.pt"):
    checkpoint = torch.load("checkpoint.pt", pickle_module=pickle)
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    epochs_completed = checkpoint["epochs_completed"]

model.train()

epochs = 5
for _ in range(epochs):
    for batch_src, batch_tgt in dataloaders["train"]:

        # Move batch to gpu, prepare model inputs.
        encoder_in = batch_src.to(device)
        decoder_in = batch_tgt[:, :-1].to(device)  # Do not include the last token.
        ground_truth = batch_tgt[:, 1:].to(
            device
        )  # Do not include the first token. The ground truth for the SOS token is thus the first word of the French sentence.

        # Create masks.
        tgt_len = decoder_in.shape[1]

        tgt_causal_mask = get_causal_mask(tgt_len, device)
        tgt_key_padding_mask = decoder_in == PAD_IDX
        src_key_padding_mask = encoder_in == PAD_IDX

        # Update weights
        optimizer.zero_grad()

        features = model(
            decoder_in,
            encoder_in,
            tgt_causal_mask,
            tgt_key_padding_mask,
            src_key_padding_mask,
        )
        loss = criterion(features.view(-1, features.shape[-1]), ground_truth.view(-1))

        print(loss)

        loss.backward()
        optimizer.step()

    epochs_completed += 1

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "epochs_completed": epochs_completed,
    },
    "checkpoint.pt",
)
# Out:
# tensor(9.6150, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7307, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.3914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9061, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9173, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9846, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8313, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6964, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6513, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5631, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6090, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5294, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4195, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3678, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1330, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1952, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1688, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0497, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9807, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0260, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8260, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8235, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8491, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8010, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6827, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6987, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4850, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4955, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3587, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5983, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4144, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3462, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2685, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2907, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2127, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0147, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2915, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1235, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1841, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0171, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0824, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0490, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8946, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0645, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0672, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0619, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9568, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7636, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0529, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9916, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8416, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9531, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9375, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9458, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8283, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0817, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9269, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7728, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7227, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7955, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6009, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5861, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8904, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7935, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8437, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8174, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9154, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5176, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5916, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8110, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7367, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5841, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7465, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5416, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4794, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7119, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7061, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5266, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4145, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5296, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5336, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6420, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5908, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5314, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7377, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5428, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5669, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5779, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7539, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5176, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7033, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8341, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7085, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4643, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4950, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4419, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5909, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4032, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2759, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4319, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3964, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5238, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5005, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3703, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1920, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5767, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3695, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2957, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2826, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3054, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0458, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1220, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2152, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1677, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0936, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3620, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2159, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3701, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2435, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2491, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3120, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4563, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0637, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8435, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3369, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9097, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8574, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9924, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9656, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1830, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2746, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0590, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1417, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0184, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0841, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0271, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0975, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9060, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9752, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1255, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1048, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9686, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2314, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0837, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6957, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2052, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8536, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9641, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0883, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9332, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9770, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6135, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8693, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0472, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1406, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6913, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9263, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8088, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6952, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1653, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7167, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0108, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9179, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8626, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7446, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5984, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7362, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5711, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8075, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0030, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5330, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1854, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1092, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9288, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6947, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8962, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4986, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0620, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7762, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0780, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6538, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8786, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8522, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8766, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6632, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0499, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7491, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7033, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7087, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7588, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7597, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7379, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8161, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8189, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0644, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6868, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8587, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7857, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8997, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5823, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2286, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8158, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6192, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0917, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5084, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9904, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8849, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7753, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6908, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6863, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9156, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2828, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4242, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4073, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7251, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4076, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6993, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7264, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6275, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2394, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7459, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7347, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4910, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7476, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7074, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5659, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4790, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6849, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4318, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7927, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7941, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7381, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6694, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7423, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5356, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4271, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5757, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5879, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6190, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5185, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6308, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3840, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5645, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6477, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5080, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6262, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3678, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5795, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6492, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4419, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5702, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6552, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6976, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5180, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4881, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7935, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6814, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5414, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4479, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5221, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3867, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3860, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5760, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3453, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3121, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8846, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4561, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3604, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6400, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9978, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2158, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6940, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4810, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7203, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5178, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5434, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8468, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1394, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9194, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4766, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5963, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4690, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6621, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4505, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2908, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3796, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4196, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4157, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4538, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5691, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1960, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3146, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2243, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3911, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3348, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2060, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4279, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3552, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8588, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5126, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6251, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4700, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5318, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1732, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5017, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5121, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7469, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3178, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3776, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3882, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4099, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3658, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3279, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5181, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0424, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9763, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2309, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5265, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2531, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1716, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2380, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1644, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4408, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1672, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4614, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3697, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1086, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3802, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4258, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9540, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1639, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2569, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2663, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0937, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3446, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1315, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0127, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0770, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1154, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5930, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2913, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5434, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7334, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3395, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0337, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2104, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4437, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3329, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9764, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9186, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4262, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3174, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3812, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3851, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2806, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1089, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1584, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3931, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8895, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1330, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0442, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4991, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7561, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9490, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5071, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3144, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2921, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0171, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9054, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5573, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4209, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2749, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1151, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7915, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8060, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3247, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0924, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3073, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3152, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1580, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5835, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0280, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3991, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0492, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1537, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9677, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3874, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9424, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2218, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1808, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3306, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1567, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9730, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9405, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7834, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7167, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6239, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1655, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1350, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1614, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7789, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3902, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9872, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4800, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2713, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7742, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3547, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2597, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2199, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2220, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2399, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2296, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0497, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2213, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0637, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1610, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2847, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1734, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5400, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0302, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3084, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1487, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1607, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9909, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1283, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9256, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0424, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0434, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7276, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2236, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4735, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8485, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1288, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1699, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9171, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9085, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1149, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0709, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9394, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3854, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0468, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7884, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0335, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9216, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1221, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7463, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1167, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9895, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2997, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9475, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2833, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0639, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4491, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9730, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7674, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3617, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9205, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1085, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4815, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4818, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9194, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3983, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0600, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9552, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9645, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9651, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7685, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8457, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9929, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1905, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9851, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0982, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0304, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9253, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8199, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1044, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1712, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1592, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9368, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1112, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3595, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0338, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8217, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9269, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6495, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1397, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1608, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1801, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8441, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8231, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2965, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1159, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8879, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9200, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3762, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9740, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9731, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9980, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1332, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3913, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7217, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9252, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6882, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0820, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2476, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4963, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7996, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0087, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4924, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1921, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2397, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1220, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0912, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3029, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3089, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8142, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1520, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4255, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1945, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0962, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2808, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1210, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5554, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0710, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9199, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6537, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6119, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7932, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1220, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8722, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1973, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9565, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3080, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8294, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0322, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3580, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7993, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0767, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2108, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1590, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0448, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6049, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0181, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8269, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7223, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6929, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5673, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7006, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8059, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1280, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6362, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0567, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9566, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8768, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7285, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9805, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0231, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0816, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3207, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8451, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9729, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0760, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0798, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7567, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3238, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8796, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8454, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8115, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9867, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4045, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2195, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8076, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0891, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1383, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1454, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1760, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5822, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6539, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2812, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8731, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2301, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4421, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8452, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8218, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3352, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5271, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7941, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0699, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7006, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9493, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1441, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9446, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0874, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1469, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9077, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8836, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1117, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1972, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8195, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1109, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0294, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8457, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5927, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1758, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7377, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5817, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9295, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1421, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6789, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7235, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6439, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7633, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2934, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7992, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0183, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1208, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0966, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9151, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1872, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4709, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7634, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0246, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8444, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8495, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8623, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8577, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8414, device='cuda:0', grad_fn=<NllLossBackward0>)
# ...
# tensor(1.8185, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2213, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3173, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5443, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6435, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0151, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8677, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3539, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7115, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8850, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4306, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6518, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4569, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6882, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9048, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6504, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5215, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9440, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4103, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4136, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7285, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6643, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0997, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4208, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6337, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5587, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0484, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2368, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7323, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9483, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2835, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1606, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8093, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0111, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4933, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6571, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7284, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6249, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7466, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6943, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7779, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4633, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6369, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8123, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0329, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7773, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0898, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3436, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1756, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9993, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3759, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8344, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6335, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4930, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6987, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6835, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5372, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7160, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9114, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9309, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7975, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6266, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5194, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8426, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8123, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1631, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4222, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9144, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8636, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2569, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6697, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6303, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0402, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8463, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6103, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9696, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6591, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7501, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4419, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7840, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0522, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8883, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6474, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5628, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6361, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5624, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2178, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9185, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5656, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6683, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6875, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8691, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6582, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3527, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4100, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9976, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0160, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4779, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7860, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9335, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4257, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4095, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5476, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1339, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8284, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7251, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5666, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6901, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7070, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5149, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0009, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0910, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5309, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8146, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6512, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7771, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2529, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8081, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7960, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5699, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6868, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5287, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6767, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0944, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7671, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6527, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0827, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9799, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5554, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5312, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5587, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0568, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7382, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7811, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3108, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4872, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9951, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7564, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7754, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0840, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3560, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7268, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9790, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6143, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7119, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0197, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6077, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9594, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5544, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3693, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5506, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6907, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6252, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7594, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3053, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2248, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6810, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6735, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3378, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8633, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6245, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9167, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9230, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8118, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9238, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2437, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7255, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8492, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8770, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6535, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5217, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8199, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6230, device='cuda:0', grad_fn=<NllLossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 72
#      68     loss = criterion(features.view(-1, features.shape[-1]), ground_truth.view(-1))
#      70     print(loss)
# ---> 72     loss.backward()
#      73     optimizer.step()
#      75 epochs_completed += 1
#
# File ~/miniconda3/envs/torch_env/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/miniconda3/envs/torch_env/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/torch_env/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# The number of epochs completed in this demo notebook, for the example below:
epochs_completed
# Out:
# 0

# %%
batches = iter(dataloaders["train"])

X_src, X_tgt = next(batches)
X_src = X_src.to(device)
X_tgt = X_tgt.to(device)

X_src = X_src[:1, :]
src_key_padding_mask = X_src == PAD_IDX

model.eval()
with torch.no_grad():
    sentence = model.generate(X_src, src_key_padding_mask, 7, 60, SOS_IDX, PAD_IDX)

print("English sentence:", en_vocab.to_words(X_src[0]))
print("French sentence ground truth:", fr_vocab.to_words(X_tgt[0]))
print("Model output:", fr_vocab.to_words(sentence))
# Out:
# English sentence: a teenage girl wearing a t - shirt and bathing suit bottom jumps into a body of water .
# French sentence ground truth: une adolescente vêtue d' un t - shirt et d' un bas de maillot saute dans un plan d' eau .
# Model output: shish falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises falaises
