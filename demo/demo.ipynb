# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Model creation and training.
import torch
import torch.nn as nn
from transformer_components import (
    TransformerDecoder,
    TransformerEncoder,
    TransformerEncoderDecoder,
    get_causal_mask,
)
from torch.optim import Adam
import pickle

# Data download and decompression.
import os
import requests
import gzip
import shutil

# Data processing
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader
import spacy

# %%
# Set device to gpu if available
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
print("You are using device: %s" % device)
# Out:
# You are using device: cuda

# %% [markdown]
# ## Download and decompress the training, validation and test data.

# %%
MULTI30_URL = (
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/"
)
LOCAL_DATA_DIR = "multi30k"
DATA_FILES_CONFIG = {
    "train": {"en": "train.en.gz", "fr": "train.fr.gz"},
    "val": {"en": "val.en.gz", "fr": "val.fr.gz"},
    "test": {"en": "test_2016_flickr.en.gz", "fr": "test_2016_flickr.fr.gz"},
}
DATA_FILES_NAMES = [
    filename for split in DATA_FILES_CONFIG.values() for filename in split.values()
]

# Download data into a local directory.
os.makedirs(LOCAL_DATA_DIR, exist_ok=True)

for file_name in DATA_FILES_NAMES:

    local_path = os.path.join(LOCAL_DATA_DIR, file_name)
    decompressed_path = os.path.splitext(local_path)[0]

    if not os.path.exists(decompressed_path):

        # Download file.
        with requests.get(
            os.path.join(MULTI30_URL, file_name), stream=True
        ) as response:
            response.raise_for_status()
            with open(local_path, "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    f.write(chunk)

        # Decompress file.
        with gzip.open(local_path, "rb") as f_in:
            with open(decompressed_path, "wb") as f_out:
                shutil.copyfileobj(f_in, f_out)

        # Remove compressed version of file.
        os.remove(local_path)

# %% [markdown]
# ## Load the data from files into ram, and tokenize.

# %%
# To save time, save the data object. That way, spacy only needs tokenize the data once.
if os.path.exists("data_cache.pt"):
    data = torch.load("data_cache.pt", pickle_module=pickle)
else:
    spacy_en = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    spacy_fr = spacy.load("fr_core_news_sm", disable=["parser", "ner"])

    def load_data(eng_file_path, fr_file_path):

        pairs = []
        with open(eng_file_path, "r") as f1, open(fr_file_path, "r") as f2:
            for eng_line, fr_line in zip(f1, f2):
                eng_tokens = [
                    token.text.lower() for token in spacy_en(eng_line.strip())
                ]
                fr_tokens = [token.text.lower() for token in spacy_fr(fr_line.strip())]
                pairs.append((eng_tokens, fr_tokens))

        return pairs

    data = {}
    for split, langs in DATA_FILES_CONFIG.items():
        eng_file_path = os.path.join(LOCAL_DATA_DIR, os.path.splitext(langs["en"])[0])
        fr_file_path = os.path.join(LOCAL_DATA_DIR, os.path.splitext(langs["fr"])[0])

        data[split] = load_data(eng_file_path, fr_file_path)

    torch.save(data, "data_cache.pt")

data["train"][0]  # Example
# Out:
# (['two',
#   'young',
#   ',',
#   'white',
#   'males',
#   'are',
#   'outside',
#   'near',
#   'many',
#   'bushes',
#   '.'],
#  ['deux',
#   'jeunes',
#   'hommes',
#   'blancs',
#   'sont',
#   'dehors',
#   'près',
#   'de',
#   'buissons',
#   '.'])

# %% [markdown]
# ## Create English and French vocabularies.

# %%
PAD_TOKEN, PAD_IDX = "<PAD>", 0
SOS_TOKEN, SOS_IDX = "<SOS>", 1
EOS_TOKEN, EOS_IDX = "<EOS>", 2
UNK_TOKEN, UNK_IDX = "<UNK>", 3


class Vocab:

    def __init__(self):

        self.word_to_ordinal = {
            PAD_TOKEN: PAD_IDX,
            SOS_TOKEN: SOS_IDX,
            EOS_TOKEN: EOS_IDX,
            UNK_TOKEN: UNK_IDX,
        }
        self.ordinal_to_word = {
            PAD_IDX: PAD_TOKEN,
            SOS_IDX: SOS_TOKEN,
            EOS_IDX: EOS_TOKEN,
            UNK_IDX: UNK_TOKEN,
        }
        self.count = 4

    # This method builds the vocabulary, for each sentence passed in.
    def add_sentence(self, sentence):

        for word in sentence:
            if word not in self.word_to_ordinal:
                self.word_to_ordinal[word] = self.count
                self.ordinal_to_word[self.count] = word
                self.count += 1

    # This method is for creating model inputs.
    def to_ordinals(self, sentence):

        ordinal_sentence = [SOS_IDX]
        for word in sentence:
            ordinal_sentence.append(self.word_to_ordinal.get(word, UNK_IDX))
        ordinal_sentence.append(EOS_IDX)

        return torch.tensor(ordinal_sentence, dtype=torch.int64)

    # This method is for viewing model outputs.
    def to_words(self, ordinal_sentence):

        tokens = []
        for ordinal in ordinal_sentence:
            ordinal = ordinal.item()
            if ordinal == EOS_IDX:
                break
            if ordinal != SOS_IDX and ordinal != PAD_IDX:
                tokens.append(self.ordinal_to_word.get(ordinal, UNK_TOKEN))

        return " ".join(tokens)


# Build the vocabularies from training data.
en_vocab = Vocab()
fr_vocab = Vocab()

for en_fr_pair in data["train"]:
    en_vocab.add_sentence(en_fr_pair[0])
    fr_vocab.add_sentence(en_fr_pair[1])

# %% [markdown]
# ## Creating a dataloader for train, val, and test datasets.

# %%
class Multi30k(Dataset):

    def __init__(self, pairs, en_vocab, fr_vocab):
        super().__init__()

        self.ordinal_pairs = []
        for pair in pairs:
            ordinal_pair = (
                en_vocab.to_ordinals(pair[0]),
                fr_vocab.to_ordinals(pair[1]),
            )
            self.ordinal_pairs.append(ordinal_pair)

    def __len__(self):
        return len(self.ordinal_pairs)

    def __getitem__(self, index):
        return self.ordinal_pairs[index]

# %%
BATCH_SIZE = 16


def collate_fn(batch):
    X_src = pad_sequence(
        [batch[i][0] for i in range(len(batch))],
        batch_first=True,
        padding_value=PAD_IDX,
    )
    X_tgt = pad_sequence(
        [batch[i][1] for i in range(len(batch))],
        batch_first=True,
        padding_value=PAD_IDX,
    )
    return (X_src, X_tgt)


dataloaders = {}
for split, pairs in data.items():
    dataset = Multi30k(pairs, en_vocab, fr_vocab)
    dataloaders[split] = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=(split == "train"),  # Shuffle only True for training data
        collate_fn=collate_fn,
    )

# %% [markdown]
# ## Model creation and training loop.

# %%
# Wrapper for the TransformerEncoder that embeds tokens and adds positional encodings.
class Encoder(nn.Module):

    def __init__(self, transformer_encoder_config, vocab_size, context_size):
        super().__init__()

        self.embedding = nn.Embedding(
            vocab_size, transformer_encoder_config["hidden_size"]
        )
        self.positional_encoding = nn.Embedding(
            context_size, transformer_encoder_config["hidden_size"]
        )
        self.transformer_encoder = TransformerEncoder(**transformer_encoder_config)

    def forward(self, X, key_padding_mask):

        X = self.embedding(X) + self.positional_encoding(
            torch.arange(X.shape[1], device=X.device)
        )
        X = self.transformer_encoder(X, key_padding_mask)

        return X


# Similar idea to above.
class Decoder(nn.Module):

    def __init__(self, transformer_decoder_config, vocab_size, context_size):
        super().__init__()

        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(
            vocab_size, transformer_decoder_config["hidden_size"]
        )
        self.positional_encoding = nn.Embedding(
            context_size, transformer_decoder_config["hidden_size"]
        )
        self.project = nn.Linear(
            transformer_decoder_config["hidden_size"],
            vocab_size,
        )
        self.transformer_decoder = TransformerDecoder(**transformer_decoder_config)

    def forward(
        self, X_tgt, X_src, tgt_mask, tgt_key_padding_mask, src_key_padding_mask
    ):

        X_tgt = self.embedding(X_tgt) + self.positional_encoding(
            torch.arange(X_tgt.shape[1], device=X_tgt.device)
        )
        features = self.transformer_decoder(
            X_tgt, X_src, tgt_mask, tgt_key_padding_mask, src_key_padding_mask
        )
        logits = self.project(features)

        return logits

# %%
CONTEXT_SIZE = 60  # The number of positional encodings to learn.

encoder_config = {
    "stack_size": 6,
    "num_heads": 8,
    "hidden_size": 512,
    "key_size": 64,
    "value_size": 64,
    "feedforward_size": 2048,
    "dropout": 0.1,
}

decoder_config = {
    "stack_size": 6,
    "num_heads": 8,
    "hidden_size": 512,
    "key_size": 64,
    "value_size": 64,
    "feedforward_size": 2048,
    "dropout": 0.1,
}

model = TransformerEncoderDecoder(
    Encoder(encoder_config, vocab_size=en_vocab.count, context_size=CONTEXT_SIZE),
    Decoder(decoder_config, vocab_size=fr_vocab.count, context_size=CONTEXT_SIZE),
).to(device)
criterion = torch.nn.CrossEntropyLoss(ignore_index=PAD_IDX)
optimizer = Adam(model.parameters(), lr=0.0001)

epochs_completed = 0

if os.path.exists("checkpoint.pt"):
    checkpoint = torch.load("checkpoint.pt", pickle_module=pickle)
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    epochs_completed = checkpoint["epochs_completed"]

model.train()

epochs = 5
for _ in range(epochs):
    for batch_src, batch_tgt in dataloaders["train"]:

        # Move batch to gpu, prepare model inputs.
        encoder_in = batch_src.to(device)
        decoder_in = batch_tgt[:, :-1].to(device)  # Do not include the last token.
        ground_truth = batch_tgt[:, 1:].to(
            device
        )  # Do not include the first token. The ground truth for the SOS token is thus the first word of the French sentence.

        # Create masks.
        tgt_len = decoder_in.shape[1]

        tgt_causal_mask = get_causal_mask(tgt_len, device)
        tgt_key_padding_mask = decoder_in == PAD_IDX
        src_key_padding_mask = encoder_in == PAD_IDX

        # Update weights
        optimizer.zero_grad()

        features = model(
            decoder_in,
            encoder_in,
            tgt_causal_mask,
            tgt_key_padding_mask,
            src_key_padding_mask,
        )
        loss = criterion(features.view(-1, features.shape[-1]), ground_truth.view(-1))

        print(loss)

        loss.backward()
        optimizer.step()

    epochs_completed += 1

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "epochs_completed": epochs_completed,
    },
    "checkpoint.pt",
)
# Out:
# tensor(9.4698, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.2795, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9701, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0297, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8578, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.7181, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6798, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6979, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5347, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3744, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4276, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2578, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2876, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2116, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0814, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1418, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1659, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9859, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7781, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9857, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8743, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5871, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8135, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6916, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6367, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7095, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4430, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4628, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0728, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1789, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5051, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1801, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2802, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2400, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8821, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1366, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0468, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0779, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9904, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9930, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.1556, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0280, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9528, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7269, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8794, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7614, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0118, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9264, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8171, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6659, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7787, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8197, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6966, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9323, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8625, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7560, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5507, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6710, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8614, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6127, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7763, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5036, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7703, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8685, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4995, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6938, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6755, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3611, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3072, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5091, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7468, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3984, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3291, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3884, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5086, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7778, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5306, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4459, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5029, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1846, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2891, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4603, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6249, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2326, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6093, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1655, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1986, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2103, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1887, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2607, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2591, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0262, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1962, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3081, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3528, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8527, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3490, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1145, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3595, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2365, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1606, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3926, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4117, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0837, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0273, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0877, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3169, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9479, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0825, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0792, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0305, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2313, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1487, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1604, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6317, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9527, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2436, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4410, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9128, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9632, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9361, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1119, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0090, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1751, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7941, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0834, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9740, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0129, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0520, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8655, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2831, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1156, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9759, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1933, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9352, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1368, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9460, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0377, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1985, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0370, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0227, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7693, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8227, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1282, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8729, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0219, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0847, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1522, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2995, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0310, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8715, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6642, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9478, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3997, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1845, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7951, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9581, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9129, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1311, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0710, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0408, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1205, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8267, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6858, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6626, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8911, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5954, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1439, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0305, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9572, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1315, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8210, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0176, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6793, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8307, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7074, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5106, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8980, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7821, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5
device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2049, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0042, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0765, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8672, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5221, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6808, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0436, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6471, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4962, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7212, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6766, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7806, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6746, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6849, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7180, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9983, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5432, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1251, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5929, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9188, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5375, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1860, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9505, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9072, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8404, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4524, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2856, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8822, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0102, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6334, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5788, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5744, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8782, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7142, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5934, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6145, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6035, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6033, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4806, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8393, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6734, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1631, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0825, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0748, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0853, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9456, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4229, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4116, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6826, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6035, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6829, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9580, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2449, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5642, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8980, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9890, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6691, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6043, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5231, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6927, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7183, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6249, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6209, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7236, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8382, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7163, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4747, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4329, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6727, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4784, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1207, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6154, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5456, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9284, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8725, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3669, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6137, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7532, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2481, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6502, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0370, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7598, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8092, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8408, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9780, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9788, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7314, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5960, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6208, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5560, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7046, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7300, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1966, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8430, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3811, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8965, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8372, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9411, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0752, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8749, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3548, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7115, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6990, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7022, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9012, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8834, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7225, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1310, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5968, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5921, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5879, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8400, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7135, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9516, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7881, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5958, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6376, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9073, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9905, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1670, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7821, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2455, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7368, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4750, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0826, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8326, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4843, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5497, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4113, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6805, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7360, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9782, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6427, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8015, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9872, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0842, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1390, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8972, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8203, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6482, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6764, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0330, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7106, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8088, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8272, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6341, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5275, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5524, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4703, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6833, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8268, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6150, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6596, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9236, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5037, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7174, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7638, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4861, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5548, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5144, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6464, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1699, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1502, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0855, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8748, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6063, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6150, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9531, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5234, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4790, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4813, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
# The number of epochs completed in this demo notebook, for the example below:
epochs_completed
# Out:
# 5

# %%
batches = iter(dataloaders["train"])

X_src, X_tgt = next(batches)
X_src = X_src.to(device)
X_tgt = X_tgt.to(device)

X_src = X_src[:1, :]
src_key_padding_mask = X_src == PAD_IDX

model.eval()
with torch.no_grad():
    sentence = model.generate(X_src, src_key_padding_mask, 7, 60, SOS_IDX, PAD_IDX)

print("English sentence:", en_vocab.to_words(X_src[0]))
print("French sentence ground truth:", fr_vocab.to_words(X_tgt[0]))
print("Model output:", fr_vocab.to_words(sentence))
# Out:
# English sentence: a man wearing a green shirt skateboarding down a street .
# French sentence ground truth: un homme vêtu d' un t - shirt vert descendant une rue en skateboard .
# Model output: un homme vêtu d' un t - shirt vert dans une rue .
